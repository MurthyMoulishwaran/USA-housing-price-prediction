# %%
import pandas as pd
usa = pd.read_csv(r"D:\python data set\USA_Housing.csv")
usa
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
usa.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
usa.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split as tts

# %%
x=usa[['Avg. Area Income','Avg. Area House Age','Avg. Area Number of Rooms','Avg. Area Number of Bedrooms','Area Population']]
y=usa.Price
x
y
# Out:
# 0       1.059034e+06
# 1       1.505891e+06
# 2       1.058988e+06
# 3       1.260617e+06
# 4       6.309435e+05
#             ...
# 4995    1.060194e+06
# 4996    1.482618e+06
# 4997    1.030730e+06
# 4998    1.198657e+06
# 4999    1.298950e+06
# Name: Price, Length: 5000, dtype: float64

# %%
x_train,x_test,y_train,y_test=tts(x,y,test_size=0.4,random_state=200)
x_train
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 3400      56228.738824             5.234700                   9.118487
# 2084      73257.265453             3.647655                   5.692281
# 656       58301.732719             4.923842                   8.058463
# 3143      84824.220626             5.866066                   7.229112
# 1341      53432.586569             6.676447                   8.553895
# ...                ...                  ...                        ...
# 844       39411.652788             4.385845                   7.047435
# 2858      77947.464364             6.441789                   7.193404
# 784       73185.620206             5.814262                   6.967135
# 4713      62637.593772             5.978158                   7.439756
# 1818      61704.342164             5.320240                   7.249122
#
#       Avg. Area Number of Bedrooms  Area Population
# 3400                          5.29     36567.178047
# ...

# %%
y_train
# Out:
# 3400    1.000842e+06
# 2084    1.049007e+06
# 656     8.905599e+05
# 3143    1.273629e+06
# 1341    1.176421e+06
#             ...
# 844     5.394834e+05
# 2858    1.539129e+06
# 784     1.462361e+06
# 4713    1.071013e+06
# 1818    8.496569e+05
# Name: Price, Length: 3000, dtype: float64

# %%
x_test
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 3019      61536.557216             6.670543                   6.994016
# 2198      59828.795108             5.515548                   8.061238
# 432       51992.743291             7.186340                   7.138234
# 2789      67877.023337             5.678509                   6.320235
# 305       69878.774199             7.218331                   6.249192
# ...                ...                  ...                        ...
# 3785      51026.019210             4.868855                   7.204505
# 2817      69446.455214             6.755067                   8.500982
# 338       85707.078753             4.374148                   6.350157
# 4997      63390.686886             7.250591                   4.805081
# 4918      64909.041149             6.636131                   9.054827
#
#       Avg. Area Number of Bedrooms  Area Population
# 3019                          2.15     29346.720905
# ...

# %%
y_test
# Out:
# 3019    1.151342e+06
# 2198    1.384966e+06
# 432     1.012263e+06
# 2789    8.436508e+05
# 305     1.197515e+06
#             ...
# 3785    4.261005e+05
# 2817    1.738788e+06
# 338     9.660844e+05
# 4997    1.030730e+06
# 4918    1.577850e+06
# Name: Price, Length: 2000, dtype: float64

# %%
from sklearn.linear_model import LinearRegression as LR
from sklearn.base import RegressorMixin as rm

lr = LR()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pre=lr.predict(x_test)
pre
# Out:
# array([1086555.26071897, 1268081.48607035,  871640.68816364, ...,
#         863591.70374332, 1017353.82706606, 1607725.95680637])

# %%
from sklearn.metrics import r2_score,root_mean_squared_error,f1_score,mean_absolute_error,mean_squared_error
score = r2_score(y_test,pre)*100
score
# Out:
# 91.67846553359968

# %%
import tkinter as tk
from tkinter import ttk
from PIL import Image, ImageTk

# Create a tkinter window
window = tk.Tk()
window.title("Ad Click Prediction")

# Set background color
bg_img = Image.open(r"C:\Users\Moulishwaran\OneDrive\Pictures\m.png")
bg_img =bg_img.resize((350,350), Image.LANCZOS)
bg_photo = ImageTk.PhotoImage(bg_img)

background_label = tk.Label(window, image=bg_photo)
background_label.image = bg_photo
background_label.place(x=0, y=0 ,relwidth=1,relheight=1)

window.configure(background = '#f0f0f0')
# Create labels and entry fields for input features
ttk.Label(window, text="Avg. Area Income", background='#f0f0f0').grid(row=0, column=0, padx=10, pady=5)
entry_income = ttk.Entry(window)
entry_income.grid(row=0, column=1, padx=10, pady=5)

ttk.Label(window, text="Avg. Area House Age", background='#f0f0f0').grid(row=1, column=0, padx=10, pady=5)
entry_house_age = ttk.Entry(window)
entry_house_age.grid(row=1, column=1, padx=10, pady=5)

ttk.Label(window, text="Avg. Area Number of Rooms", background='#f0f0f0').grid(row=2, column=0, padx=10, pady=5)
entry_num_rooms = ttk.Entry(window)
entry_num_rooms.grid(row=2, column=1, padx=10, pady=5)

ttk.Label(window, text="Avg. Area Number of Bedrooms", background='#f0f0f0').grid(row=3, column=0, padx=10, pady=5)
entry_num_bedrooms = ttk.Entry(window)
entry_num_bedrooms.grid(row=3, column=1, padx=10, pady=5)

ttk.Label(window, text="Area Population", background='#f0f0f0').grid(row=4, column=0, padx=10, pady=5)
entry_population = ttk.Entry(window)
entry_population.grid(row=4, column=1, padx=10, pady=5)

# Load the refresh image
refresh_img = Image.open(r"C:\Users\Moulishwaran\OneDrive\Pictures\refresh-button.png")  # Replace "path_to_refresh_image.png" with your image file path
refresh_img = refresh_img.resize((42, 42), Image.LANCZOS)  # Resize the image using LANCZOS resampling
refresh_icon = ImageTk.PhotoImage(refresh_img)

# Function to predict ad click
def predict_click():
    
    # Get input values
    Avg_Area_Income = float(entry_income.get())
    Avg_Area_House_Age= float(entry_house_age.get())
    Avg_Area_Number_of_Rooms=float(entry_num_rooms.get())
    Avg_Area_Number_of_Bedrooms= float(entry_num_bedrooms.get())
    Area_Population= float(entry_population.get())
    
    
    
    
    # Make prediction using the trained model
    prediction = lr.predict(np.array([[Avg_Area_Income, Avg_Area_House_Age, Avg_Area_Number_of_Rooms, Avg_Area_Number_of_Bedrooms, Area_Population]]))
    result_label.config(text="Prediction: {}".format(prediction[0]), foreground="#007bff")

# Button to trigger prediction
predict_button = ttk.Button(window, text="Predict", command=predict_click, style="Predict.TButton")
predict_button.grid(row=5, column=1, columnspan=3, padx=10, pady=5)

result_label = ttk.Label(window, text="", background='#f0f0f0', foreground='#007bff', font=('Helvetica', 12, 'bold'))
result_label.grid(row=6, column=1, columnspan=2, padx=10, pady=5)

# Function to clear input fields and prediction result
def refresh_fields():
    entry_income.delete(0, 'end')
    entry_house_age.delete(0, 'end')
    entry_num_rooms.delete(0, 'end')
    entry_num_bedrooms.delete(0, 'end')
    entry_population.delete(0, 'end')

# Button to clear input fields and prediction result using an image
refresh_button = ttk.Button(window, image=refresh_icon, command=refresh_fields)
refresh_button.image = refresh_icon  # Keep a reference to the image object
refresh_button.grid(row=8, column=1, columnspan=1, padx=10, pady=5)




# Train your model
# Assuming x_train, y_train are already defined
lr = LinearRegression()
lr.fit(x_train, y_train)
# Start the GUI event loop
window.mainloop()

# %%
import numpy as np
lr.predict(np.array([[83953.104839,7.385135,6.898847,3.08,37283.357646]]))
